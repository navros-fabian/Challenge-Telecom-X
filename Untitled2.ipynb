# %% [markdown]
# <a href="https://colab.research.google.com/github/navros-fabian/Challenge-Telecom-X/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'
df = pd.read_json(url)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# ##🔧 Transformación
# ###Normalización de columnas

# %%
columnas = list(df.columns[2:])
columnas
# Out:
# ['customer', 'phone', 'internet', 'account']

# %%
columnas_normalizadas = pd.DataFrame()

for columna in columnas:
  columna_normalizada = pd.json_normalize(df[columna])
  columnas_normalizadas = pd.concat([columnas_normalizadas, columna_normalizada], axis=1)

# %%
df = pd.concat([df.drop(columns=columnas), columnas_normalizadas], axis=1)

# %%
#Para visualizar todas las columnas
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  Charges.Monthly Charges.Total
# 0              Yes      Mailed check             65.6         593.3
# 1               No      Mailed check             59.9         542.4
# 2              Yes  Electronic check             73.9        280.85
# 3              Yes  Electronic check             98.0       1237.85
# 4              Yes      Mailed check             83.9         267.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
# "Charges.total" tiene cadenas vacias, por este motivo los convertimos a NaN
df['Charges.Total'] = df['Charges.Total'].replace(' ', np.nan).astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7256 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
columnas_object = df.select_dtypes(include='object').columns.to_list()
columnas_object
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
# Creamos un DataFrame para visualizar los valores unicos presentes en cada columna object
lista_valores_unicos = []
for col in columnas_object[1:]:
  lista_valores_unicos.append(pd.DataFrame({col: df[col].unique()}))

valores_unicos = pd.concat(lista_valores_unicos, axis=1)
valores_unicos
# Out:
#   Churn  gender Partner Dependents PhoneService     MultipleLines  \
# 0    No  Female     Yes        Yes          Yes                No
# 1   Yes    Male      No         No           No               Yes
# 2           NaN     NaN        NaN          NaN  No phone service
# 3   NaN     NaN     NaN        NaN          NaN               NaN
#
#   InternetService       OnlineSecurity         OnlineBackup  \
# 0             DSL                   No                  Yes
# 1     Fiber optic                  Yes                   No
# 2              No  No internet service  No internet service
# 3             NaN                  NaN                  NaN
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                  Yes                  Yes
# 1                  Yes                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  NaN                  NaN                  NaN
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No        One year              Yes
# 1                  Yes  Month-to-month               No
# 2  No internet service        Two year              NaN
# 3                  NaN             NaN              NaN
#
#                PaymentMethod
# 0               Mailed check
# 1           Electronic check
# 2    Credit card (automatic)
# 3  Bank transfer (automatic)

# %%
# Notamos que "Churn" tiene registros en blanco
(df['Churn'] == '').sum()
# Out:
# np.int64(224)

# %%
df[df['Churn'] == '']
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX        Female              0      No         No      14
# 7180  9872-RZQQB        Female              0     Yes         No      49
# 7211  9920-GNDMB          Male              0      No         No       9
# 7239  9955-RVWSC        Female              0     Yes        Yes      67
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 30            Yes               Yes     Fiber optic                  Yes
# 75            Yes                No              No  No internet service
# 96            Yes                No             DSL                  Yes
# 98            Yes                No             DSL                  Yes
# 175           Yes               Yes     Fiber optic                   No
# ...           ...               ...             ...                  ...
# 7158          Yes               Yes             DSL                   No
# 7180           No  No phone service             DSL                  Yes
# 7211          Yes               Yes     Fiber optic                   No
# 7239          Yes                No              No  No internet service
# 7247          Yes                No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 30                     No                   No                   No
# 75    No internet service  No internet service  No internet service
# 96                    Yes                   No                  Yes
# 98                    Yes                   No                  Yes
# 175                   Yes                  Yes                   No
# ...                   ...                  ...                  ...
# 7158                  Yes                   No                   No
# 7180                   No                   No                   No
# 7211                   No                   No                   No
# 7239  No internet service  No internet service  No internet service
# 7247  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 30                     No                   No  Month-to-month
# 75    No internet service  No internet service        Two year
# 96                     No                   No        One year
# 98                     No                   No  Month-to-month
# 175                   Yes                  Yes        One year
# ...                   ...                  ...             ...
# 7158                   No                   No        One year
# 7180                  Yes                   No  Month-to-month
# 7211                   No                   No  Month-to-month
# 7239  No internet service  No internet service        Two year
# 7247  No internet service  No internet service  Month-to-month
#
#      PaperlessBilling              PaymentMethod  Charges.Monthly  \
# 30                Yes  Bank transfer (automatic)            79.00
# 75                Yes    Credit card (automatic)            19.90
# 96                Yes           Electronic check            58.75
# 98                 No    Credit card (automatic)            59.90
# 175               Yes  Bank transfer (automatic)           103.15
# ...               ...                        ...              ...
# 7158              Yes               Mailed check            54.25
# 7180               No  Bank transfer (automatic)            40.65
# 7211              Yes           Electronic check            76.25
# 7239              Yes  Bank transfer (automatic)            19.25
# 7247              Yes               Mailed check            19.55
#
#       Charges.Total
# 30           929.30
# 75          1355.10
# 96          1696.20
# 98           287.85
# 175         6792.45
# ...             ...
# 7158         773.20
# 7180        2070.75
# 7211         684.85
# 7239        1372.90
# 7247         658.95
#
# [224 rows x 21 columns]

# %%
# Convertimos los datos vacios en NaN
df['Churn'] = df['Churn'].replace('', np.nan)

# %% [markdown]
# ##Tratamiento de datos nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7256 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
df.dropna(subset=['Churn'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  Charges.Monthly   7043 non-null   float64
#  20  Charges.Total     7032 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
# Creemos que 'Charges.Monthly' * 'tenure' es un calculo logico para estimar los valores faltantes de la columna 'Charges.Total'
df.loc[df['Charges.Total'].isna(), 'Charges.Total'] = (df['tenure'] * df['Charges.Monthly'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  Charges.Monthly   7043 non-null   float64
#  20  Charges.Total     7043 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.4+ MB

# %%
"""
Notamos la presencia de algunos registros con valor 0 en "Charges.Total" y "tenure". Entendemos que son clientes nuevos que no tienen ni un mes
de permanencia en la empresa. Por lo tanto le asignamos el valor de "Charges.Monthly" a la columna "Charges.Total"
"""
df.loc[(df['Charges.Total'] == 0) & (df['tenure'] == 0), 'Charges.Total'] = df['Charges.Monthly']

# %%
# Comprobar si hay datos duplicados
df.duplicated().any()
# Out:
# np.False_

# %%
df[columnas_object[1:]] = df[columnas_object[1:]].apply(lambda x: x.str.lower())
df.head(1)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    no  female              0     yes        yes       9
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          yes            no             dsl             no          yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 0               no         yes         yes              no  one year
#
#   PaperlessBilling PaymentMethod  Charges.Monthly  Charges.Total
# 0              yes  mailed check             65.6          593.3

# %% [markdown]
# ## Renombramos las columnas

# %%
df.columns = df.columns.map({'customerID' : 'Cliente_ID', 'Churn': 'Abandono' , 'gender' : 'Genero', 'SeniorCitizen' : 'Ciudadano_mayor', 'Partner' : 'Pareja',
                'Dependents' : 'Dependientes', 'tenure' : 'Meses_permanencia', 'PhoneService' : 'Servicio_telefonico', 'MultipleLines' : 'Varias_lineas',
                'InternetService': 'Tipo_servicio_internet', 'OnlineSecurity' : 'Seguridad_en_linea', 'OnlineBackup' : 'Copia_seguridad_en_linea',
                'DeviceProtection' : 'Proteccion_dispositivo', 'TechSupport' : 'Soporte_tecnico', 'StreamingTV' : 'Televisión_por_cable',
                'StreamingMovies' : 'Streaming_peliculas', 'Contract' : 'Tipo_contrato', 'PaperlessBilling' : 'Factura_en_linea',
                'PaymentMethod' : 'Forma_pago', 'Charges.Monthly' : 'Cuenta_mensual', 'Charges.Total' : 'Cargo_total'})

# %% [markdown]
# ## Estandarización de datos:
# Convertimos valores textuales como "Sí" y "No" en valores binarios (1 y 0)

# %%
columnas_binarias = ['Abandono', 'Pareja', 'Dependientes', 'Servicio_telefonico', 'Factura_en_linea']
df[columnas_binarias] = df[columnas_binarias].replace({'yes' : 1, 'no' : 0}).infer_objects(copy=False).astype('Int64')
# Out:
# /tmp/ipykernel_416/1160258938.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[columnas_binarias] = df[columnas_binarias].replace({'yes' : 1, 'no' : 0}).infer_objects(copy=False).astype('Int64')

# %%
df['Genero'] = df['Genero'].replace({'male' : 0, 'female' : 1}).infer_objects(copy=False).astype('Int64')
# Out:
# /tmp/ipykernel_416/2881999821.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Genero'] = df['Genero'].replace({'male' : 0, 'female' : 1}).infer_objects(copy=False).astype('Int64')

# %%
# En esta variable guardamos los nombres de aquellas columnas que tienen en algunos de sus registros el valor textual "no internet service"
columnas_a_convertir = [col for col in df.columns if (df[col] == 'no internet service').any()]

# %%
columnas_a_convertir
# Out:
# ['Seguridad_en_linea',
#  'Copia_seguridad_en_linea',
#  'Proteccion_dispositivo',
#  'Soporte_tecnico',
#  'Televisión_por_cable',
#  'Streaming_peliculas']

# %%
# 'no internet service' es igual a 'no', por lo tanto igual a 0
df[columnas_a_convertir]  = df[columnas_a_convertir].replace({'yes' : 1, 'no' : 0, 'no internet service' : 0 }).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_416/3483511857.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[columnas_a_convertir]  = df[columnas_a_convertir].replace({'yes' : 1, 'no' : 0, 'no internet service' : 0 }).infer_objects(copy=False)

# %%
df['Varias_lineas'] = df['Varias_lineas'].replace({'yes' : 1, 'no' : 0, 'no phone service' : 0 }).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_416/2366803894.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Varias_lineas'] = df['Varias_lineas'].replace({'yes' : 1, 'no' : 0, 'no phone service' : 0 }).infer_objects(copy=False)

# %%
df['Tipo_servicio_internet'].unique()
# Out:
# array(['dsl', 'fiber optic', 'no'], dtype=object)

# %%
# Creamos la columna "Servicio_internet" para indicar unicamente si tiene o no contratado este servicio, independientemente del tipo contratado
df['Servicio_internet'] = df['Tipo_servicio_internet'].replace({'dsl' : 1, 'fiber optic' : 1, 'no' : 0}).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_416/1108306203.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Servicio_internet'] = df['Tipo_servicio_internet'].replace({'dsl' : 1, 'fiber optic' : 1, 'no' : 0}).infer_objects(copy=False)

# %%
df['Tipo_servicio_internet'] =df['Tipo_servicio_internet'].replace('no','no internet service' )

# %%
df.columns
# Out:
# Index(['Cliente_ID', 'Abandono', 'Genero', 'Ciudadano_mayor', 'Pareja',
#        'Dependientes', 'Meses_permanencia', 'Servicio_telefonico',
#        'Varias_lineas', 'Tipo_servicio_internet', 'Seguridad_en_linea',
#        'Copia_seguridad_en_linea', 'Proteccion_dispositivo', 'Soporte_tecnico',
#        'Televisión_por_cable', 'Streaming_peliculas', 'Tipo_contrato',
#        'Factura_en_linea', 'Forma_pago', 'Cuenta_mensual', 'Cargo_total',
#        'Servicio_internet'],
#       dtype='object')

# %% [markdown]
# ## Creamos la columna "Cuentas_diarias"

# %%
df['Cuentas_diarias'] = df['Cuenta_mensual'] / 30
df.head(2)
# Out:
#    Cliente_ID  Abandono  Genero  Ciudadano_mayor  Pareja  Dependientes  \
# 0  0002-ORFBO         0       1                0       1             1
# 1  0003-MKNFE         0       0                0       0             0
#
#    Meses_permanencia  Servicio_telefonico  Varias_lineas  \
# 0                  9                    1              0
# 1                  9                    1              1
#
#   Tipo_servicio_internet  Seguridad_en_linea  Copia_seguridad_en_linea  \
# 0                    dsl                   0                         1
# 1                    dsl                   0                         0
#
#    Proteccion_dispositivo  Soporte_tecnico  Televisión_por_cable  \
# 0                       0                1                     1
# 1                       0                0                     0
#
#    Streaming_peliculas   Tipo_contrato  Factura_en_linea    Forma_pago  \
# 0                    0        one year                 1  mailed check
# 1                    1  month-to-month                 0  mailed check
#
#    Cuenta_mensual  Cargo_total  Servicio_internet  Cuentas_diarias
# 0            65.6        593.3                  1         2.186667
# 1            59.9        542.4                  1         1.996667

# %%
nuevo_orden = ['Cliente_ID', 'Abandono', 'Genero', 'Ciudadano_mayor', 'Pareja', 'Dependientes', 'Meses_permanencia', 'Servicio_telefonico', 'Varias_lineas', 'Servicio_internet',
               'Tipo_servicio_internet', 'Seguridad_en_linea', 'Copia_seguridad_en_linea', 'Proteccion_dispositivo', 'Soporte_tecnico', 'Televisión_por_cable',
               'Streaming_peliculas', 'Tipo_contrato', 'Factura_en_linea', 'Forma_pago', 'Cuentas_diarias', 'Cuenta_mensual', 'Cargo_total']

# %%
df = df.reindex(columns=nuevo_orden)

# %%
df.head(1)
# Out:
#    Cliente_ID  Abandono  Genero  Ciudadano_mayor  Pareja  Dependientes  \
# 0  0002-ORFBO         0       1                0       1             1
#
#    Meses_permanencia  Servicio_telefonico  Varias_lineas  Servicio_internet  \
# 0                  9                    1              0                  1
#
#   Tipo_servicio_internet  Seguridad_en_linea  Copia_seguridad_en_linea  \
# 0                    dsl                   0                         1
#
#    Proteccion_dispositivo  Soporte_tecnico  Televisión_por_cable  \
# 0                       0                1                     1
#
#    Streaming_peliculas Tipo_contrato  Factura_en_linea    Forma_pago  \
# 0                    0      one year                 1  mailed check
#
#    Cuentas_diarias  Cuenta_mensual  Cargo_total
# 0         2.186667            65.6        593.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Cliente_ID                7043 non-null   object
#  1   Abandono                  7043 non-null   Int64
#  2   Genero                    7043 non-null   Int64
#  3   Ciudadano_mayor           7043 non-null   int64
#  4   Pareja                    7043 non-null   Int64
#  5   Dependientes              7043 non-null   Int64
#  6   Meses_permanencia         7043 non-null   int64
#  7   Servicio_telefonico       7043 non-null   Int64
#  8   Varias_lineas             7043 non-null   int64
#  9   Servicio_internet         7043 non-null   int64
#  10  Tipo_servicio_internet    7043 non-null   object
#  11  Seguridad_en_linea        7043 non-null   int64
#  12  Copia_seguridad_en_linea  7043 non-null   int64
#  13  Proteccion_dispositivo    7043 non-null   int64
#  14  Soporte_tecnico           7043 non-null   int64
#  15  Televisión_por_cable      7043 non-null   int64
#  16  Streaming_peliculas       7043 non-null   int64
#  17  Tipo_contrato             7043 non-null   object
#  18  Factura_en_linea          7043 non-null   Int64
#  19  Forma_pago                7043 non-null   object
#  20  Cuentas_diarias           7043 non-null   float64
#  21  Cuenta_mensual            7043 non-null   float64
#  22  Cargo_total               7043 non-null   float64
# dtypes: Int64(6), float64(3), int64(10), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
#  # Carga y análisis

# %%
df.describe()
# Out:
#        Abandono    Genero  Ciudadano_mayor    Pareja  Dependientes  \
# count    7043.0    7043.0      7043.000000    7043.0        7043.0
# mean    0.26537  0.495244         0.162147  0.483033      0.299588
# std    0.441561  0.500013         0.368612  0.499748       0.45811
# min         0.0       0.0         0.000000       0.0           0.0
# 25%         0.0       0.0         0.000000       0.0           0.0
# 50%         0.0       0.0         0.000000       0.0           0.0
# 75%         1.0       1.0         0.000000       1.0           1.0
# max         1.0       1.0         1.000000       1.0           1.0
#
#        Meses_permanencia  Servicio_telefonico  Varias_lineas  \
# count        7043.000000               7043.0    7043.000000
# mean           32.371149             0.903166       0.421837
# std            24.559481             0.295752       0.493888
# min             0.000000                  0.0       0.000000
# 25%             9.000000                  1.0       0.000000
# 50%            29.000000                  1.0       0.000000
# 75%            55.000000                  1.0       1.000000
# max            72.000000                  1.0       1.000000
#
#        Servicio_internet  Seguridad_en_linea  Copia_seguridad_en_linea  \
# count        7043.000000         7043.000000               7043.000000
# mean            0.783331            0.286668                  0.344881
# std             0.412004            0.452237                  0.475363
# min             0.000000            0.000000                  0.000000
# 25%             1.000000            0.000000                  0.000000
# 50%             1.000000            0.000000                  0.000000
# 75%             1.000000            1.000000                  1.000000
# max             1.000000            1.000000                  1.000000
#
#        Proteccion_dispositivo  Soporte_tecnico  Televisión_por_cable  \
# count             7043.000000      7043.000000           7043.000000
# mean                 0.343888         0.290217              0.384353
# std                  0.475038         0.453895              0.486477
# min                  0.000000         0.000000              0.000000
# 25%                  0.000000         0.000000              0.000000
# 50%                  0.000000         0.000000              0.000000
# 75%                  1.000000         1.000000              1.000000
# max                  1.000000         1.000000              1.000000
#
#        Streaming_peliculas  Factura_en_linea  Cuentas_diarias  Cuenta_mensual  \
# count          7043.000000            7043.0      7043.000000     7043.000000
# mean              0.387903          0.592219         2.158723       64.761692
# std               0.487307          0.491457         1.003002       30.090047
# min               0.000000               0.0         0.608333       18.250000
# 25%               0.000000               0.0         1.183333       35.500000
# 50%               0.000000               1.0         2.345000       70.350000
# 75%               1.000000               1.0         2.995000       89.850000
# max               1.000000               1.0         3.958333      118.750000
#
#        Cargo_total
# count  7043.000000
# mean   2279.798992
# std    2266.730170
# min      18.800000
# 25%     398.550000
# 50%    1394.550000
# 75%    3786.600000
# max    8684.800000

# %% [markdown]
# # Distribución de evasión

# %%
contador_abandono = df['Abandono'].value_counts()

fig, ax = plt.subplots(figsize=(6,4))
fig.suptitle('Distribución de evasión entre los clientes (Abandono)', fontsize=16)

# Definimos los colores para cada categoría
colores = ['lightgreen', 'tomato']  # verde = continúa, rojo = abandonó

ax.pie(contador_abandono,
       labels=['Continúa en la empresa', 'Abandonó la empresa'],
       autopct='%0.2f%%',
       colors=colores)

plt.show()

# %% [markdown]
# # Tasas de abandono promedio

# %% [markdown]
# ## Tasas de abandono por variables categóricas

# %%
fig, ax = plt.subplots(4,2, figsize=(15,12))
fig.suptitle('Tasas de abandonos por variables categóricas', fontsize=16)
fig.subplots_adjust(wspace=0.15, hspace=0.45)
lista_columnas_categoricas = ['Genero', 'Ciudadano_mayor', 'Pareja', 'Dependientes', 'Tipo_servicio_internet', 'Tipo_contrato', 'Forma_pago']

ax = ax.flatten()

for i, col in enumerate(lista_columnas_categoricas):
  promedio = df.groupby(col)['Abandono'].mean()

  bars = ax[i].bar(promedio.index, promedio.values)

  for bar in bars:
    altura = bar.get_height()
    ax[i].text(
        bar.get_x() + bar.get_width() / 2,
        altura,
        f'{altura*100:.1f}%',
        ha='center', va='bottom',
        fontsize=9
    )

  max_val = promedio.values.max()
  ax[i].set_ylim(0, max_val * 1.15)

  ax[i].set_title(f'Tasa de abandono por {col}')
  if i in [1,2,3]:
    ax[i].set_xticks([0, 1])
    ax[i].set_xticklabels(['No', 'Si'])
  elif i == 0:
    ax[i].set_xticks([0, 1])
    ax[i].set_xticklabels(['Masculino', 'Femenino'])
  else:
    ax[i].set_xlabel(col)
  ax[i].set_ylabel('Tasa de abandono')

ax[5].tick_params(axis='x', rotation = 45)
ax[6].tick_params(axis='x', rotation = 45)

fig.delaxes(ax[-1])

plt.show()

# %% [markdown]
# ## Tabla resumen por categórias

# %%
resumen_categorias = {}
for col in lista_columnas_categoricas:
  resumen_categorias[col] = df.groupby(col)['Abandono'].agg(
    clientes='count',
    abandonos='sum',
    tasa_abandono='mean'
  )
resumen_categorias['Genero'].rename(index={0: 'Masculino', 1: 'Femenino'}, inplace=True)

for i in ['Ciudadano_mayor', 'Pareja', 'Dependientes']:
  resumen_categorias[i].rename(index={0: 'No', 1: 'Si'}, inplace=True)

df_categorias_resumen = (
    pd.concat(resumen_categorias, names=['categoria', 'valor'])
      .reset_index()
)


estilo_resumen_categorias = df_categorias_resumen.sort_values('tasa_abandono', ascending=False).style.format({'tasa_abandono': '{:.1%}'}).background_gradient(subset=['tasa_abandono'], cmap='Reds')
estilo_resumen_categorias
# Out:
# <style type="text/css">
# #T_60aab_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_60aab_row1_col4 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_60aab_row2_col4 {
#   background-color: #8e0912;
#   color: #f1f1f1;
# }
# #T_60aab_row3_col4 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_60aab_row4_col4 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_60aab_row5_col4 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_60aab_row6_col4 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_60aab_row7_col4 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_60aab_row8_col4 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_60aab_row9_col4 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_60aab_row10_col4 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_60aab_row11_col4 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_60aab_row12_col4 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_60aab_row13_col4 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_60aab_row14_col4 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_60aab_row15_col4 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_60aab_row16_col4 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_60aab_row17_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_60aab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60aab_level0_col0" class="col_heading level0 col0" >categoria</th>
#       <th id="T_60aab_level0_col1" class="col_heading level0 col1" >valor</th>
#       <th id="T_60aab_level0_col2" class="col_heading level0 col2" >clientes</th>
#       <th id="T_60aab_level0_col3" class="col_heading level0 col3" >abandonos</th>
#       <th id="T_60aab_level0_col4" class="col_heading level0 col4" >tasa_abandono</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60aab_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_60aab_row0_col0" class="data row0 col0" >Forma_pago</td>
#       <td id="T_60aab_row0_col1" class="data row0 col1" >electronic check</td>
#       <td id="T_60aab_row0_col2" class="data row0 col2" >2365</td>
#       <td id="T_60aab_row0_col3" class="data row0 col3" >1071</td>
#       <td id="T_60aab_row0_col4" class="data row0 col4" >45.3%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_60aab_row1_col0" class="data row1 col0" >Tipo_contrato</td>
#       <td id="T_60aab_row1_col1" class="data row1 col1" >month-to-month</td>
#       <td id="T_60aab_row1_col2" class="data row1 col2" >3875</td>
#       <td id="T_60aab_row1_col3" class="data row1 col3" >1655</td>
#       <td id="T_60aab_row1_col4" class="data row1 col4" >42.7%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_60aab_row2_col0" class="data row2 col0" >Tipo_servicio_internet</td>
#       <td id="T_60aab_row2_col1" class="data row2 col1" >fiber optic</td>
#       <td id="T_60aab_row2_col2" class="data row2 col2" >3096</td>
#       <td id="T_60aab_row2_col3" class="data row2 col3" >1297</td>
#       <td id="T_60aab_row2_col4" class="data row2 col4" >41.9%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60aab_row3_col0" class="data row3 col0" >Ciudadano_mayor</td>
#       <td id="T_60aab_row3_col1" class="data row3 col1" >Si</td>
#       <td id="T_60aab_row3_col2" class="data row3 col2" >1142</td>
#       <td id="T_60aab_row3_col3" class="data row3 col3" >476</td>
#       <td id="T_60aab_row3_col4" class="data row3 col4" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60aab_row4_col0" class="data row4 col0" >Pareja</td>
#       <td id="T_60aab_row4_col1" class="data row4 col1" >No</td>
#       <td id="T_60aab_row4_col2" class="data row4 col2" >3641</td>
#       <td id="T_60aab_row4_col3" class="data row4 col3" >1200</td>
#       <td id="T_60aab_row4_col4" class="data row4 col4" >33.0%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_60aab_row5_col0" class="data row5 col0" >Dependientes</td>
#       <td id="T_60aab_row5_col1" class="data row5 col1" >No</td>
#       <td id="T_60aab_row5_col2" class="data row5 col2" >4933</td>
#       <td id="T_60aab_row5_col3" class="data row5 col3" >1543</td>
#       <td id="T_60aab_row5_col4" class="data row5 col4" >31.3%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_60aab_row6_col0" class="data row6 col0" >Genero</td>
#       <td id="T_60aab_row6_col1" class="data row6 col1" >Femenino</td>
#       <td id="T_60aab_row6_col2" class="data row6 col2" >3488</td>
#       <td id="T_60aab_row6_col3" class="data row6 col3" >939</td>
#       <td id="T_60aab_row6_col4" class="data row6 col4" >26.9%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row7" class="row_heading level0 row7" >0</th>
#       <td id="T_60aab_row7_col0" class="data row7 col0" >Genero</td>
#       <td id="T_60aab_row7_col1" class="data row7 col1" >Masculino</td>
#       <td id="T_60aab_row7_col2" class="data row7 col2" >3555</td>
#       <td id="T_60aab_row7_col3" class="data row7 col3" >930</td>
#       <td id="T_60aab_row7_col4" class="data row7 col4" >26.2%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row8" class="row_heading level0 row8" >2</th>
#       <td id="T_60aab_row8_col0" class="data row8 col0" >Ciudadano_mayor</td>
#       <td id="T_60aab_row8_col1" class="data row8 col1" >No</td>
#       <td id="T_60aab_row8_col2" class="data row8 col2" >5901</td>
#       <td id="T_60aab_row8_col3" class="data row8 col3" >1393</td>
#       <td id="T_60aab_row8_col4" class="data row8 col4" >23.6%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_60aab_row9_col0" class="data row9 col0" >Pareja</td>
#       <td id="T_60aab_row9_col1" class="data row9 col1" >Si</td>
#       <td id="T_60aab_row9_col2" class="data row9 col2" >3402</td>
#       <td id="T_60aab_row9_col3" class="data row9 col3" >669</td>
#       <td id="T_60aab_row9_col4" class="data row9 col4" >19.7%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row10" class="row_heading level0 row10" >17</th>
#       <td id="T_60aab_row10_col0" class="data row10 col0" >Forma_pago</td>
#       <td id="T_60aab_row10_col1" class="data row10 col1" >mailed check</td>
#       <td id="T_60aab_row10_col2" class="data row10 col2" >1612</td>
#       <td id="T_60aab_row10_col3" class="data row10 col3" >308</td>
#       <td id="T_60aab_row10_col4" class="data row10 col4" >19.1%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_60aab_row11_col0" class="data row11 col0" >Tipo_servicio_internet</td>
#       <td id="T_60aab_row11_col1" class="data row11 col1" >dsl</td>
#       <td id="T_60aab_row11_col2" class="data row11 col2" >2421</td>
#       <td id="T_60aab_row11_col3" class="data row11 col3" >459</td>
#       <td id="T_60aab_row11_col4" class="data row11 col4" >19.0%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row12" class="row_heading level0 row12" >14</th>
#       <td id="T_60aab_row12_col0" class="data row12 col0" >Forma_pago</td>
#       <td id="T_60aab_row12_col1" class="data row12 col1" >bank transfer (automatic)</td>
#       <td id="T_60aab_row12_col2" class="data row12 col2" >1544</td>
#       <td id="T_60aab_row12_col3" class="data row12 col3" >258</td>
#       <td id="T_60aab_row12_col4" class="data row12 col4" >16.7%</td>
#     </tr>
#     <tr>
#       <th id="T_60aab_level0_row13" class="row_heading level0 row13" >7</th>
#       <td id="T_60aab_row13_col0" class="data row13 col0" >Dependientes</td>
#       <td id="T_60aab_row13_col1" class="data row13 col1" >Si</td>
#       <td id="T_60aab_row13_col2" class="data row13 col2" >2110</td>
#       <td id="T_60aab_row13_col3" class="data row13 col3" >326</td>

# %% [markdown]
# ## Principales diferencias de tasas de abandono entre los valores de misma categoría

# %%
diferencia_tasa_var_categorias = {
    'Categoria' : ['Ciudadano_mayor', 'Tipo_servicio_internet', 'Tipo_contrato', 'Tipo_contrato', 'Forma_pago', 'Forma_pago', 'Forma_pago'],
    'Valor' : ['>= 65 años', 'Fibra optica vs dsl', 'Mes a Mes vs 1 año', 'Mes a Mes vs 2 años', 'E-cheq vs Mailed check', 'E-cheq vs bank transfer', 'E-cheq vs credit card'],
    'Diferencia absoluta' : [(df_categorias_resumen.loc[3, 'tasa_abandono'] - df_categorias_resumen.loc[2, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[9, 'tasa_abandono'] - df_categorias_resumen.loc[8, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[11, 'tasa_abandono'] - df_categorias_resumen.loc[12, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[11, 'tasa_abandono'] - df_categorias_resumen.loc[13, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[16, 'tasa_abandono'] - df_categorias_resumen.loc[17, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[16, 'tasa_abandono'] - df_categorias_resumen.loc[14, 'tasa_abandono'])*100,
                             (df_categorias_resumen.loc[16, 'tasa_abandono'] - df_categorias_resumen.loc[15, 'tasa_abandono'])*100
                             ],
    'Riesgo Relativo' : [((df_categorias_resumen.loc[3, 'tasa_abandono'] / df_categorias_resumen.loc[2, 'tasa_abandono'])-1)*100,
                         ((df_categorias_resumen.loc[9, 'tasa_abandono'] / df_categorias_resumen.loc[8, 'tasa_abandono'])-1)*100,
                         ((df_categorias_resumen.loc[11, 'tasa_abandono'] / df_categorias_resumen.loc[12, 'tasa_abandono'] )-1)*100,
                         ((df_categorias_resumen.loc[11, 'tasa_abandono'] / df_categorias_resumen.loc[13, 'tasa_abandono'] )-1)*100,
                         ((df_categorias_resumen.loc[16, 'tasa_abandono'] / df_categorias_resumen.loc[17, 'tasa_abandono'] )-1)*100,
                         ((df_categorias_resumen.loc[16, 'tasa_abandono'] / df_categorias_resumen.loc[14, 'tasa_abandono'] )-1)*100,
                         ((df_categorias_resumen.loc[16, 'tasa_abandono'] / df_categorias_resumen.loc[15, 'tasa_abandono'] )-1)*100

                             ],
}

df_diferencia_tasa_var_categorias = pd.DataFrame(diferencia_tasa_var_categorias)
df_diferencia_tasa_var_categorias.style.format({'Diferencia absoluta' : '{:.2f} pp',
                                                'Riesgo Relativo' : '{:.2f}%'}).highlight_between(left=50, right=1500, subset=['Riesgo Relativo'], color='skyblue').hide(axis='index')
# Out:
# <style type="text/css">
# #T_0dd03_row0_col3, #T_0dd03_row1_col3, #T_0dd03_row2_col3, #T_0dd03_row3_col3, #T_0dd03_row4_col3, #T_0dd03_row5_col3, #T_0dd03_row6_col3 {
#   background-color: skyblue;
# }
# </style>
# <table id="T_0dd03" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_0dd03_level0_col0" class="col_heading level0 col0" >Categoria</th>
#       <th id="T_0dd03_level0_col1" class="col_heading level0 col1" >Valor</th>
#       <th id="T_0dd03_level0_col2" class="col_heading level0 col2" >Diferencia absoluta</th>
#       <th id="T_0dd03_level0_col3" class="col_heading level0 col3" >Riesgo Relativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0dd03_row0_col0" class="data row0 col0" >Ciudadano_mayor</td>
#       <td id="T_0dd03_row0_col1" class="data row0 col1" >>= 65 años</td>
#       <td id="T_0dd03_row0_col2" class="data row0 col2" >18.08 pp</td>
#       <td id="T_0dd03_row0_col3" class="data row0 col3" >76.57%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row1_col0" class="data row1 col0" >Tipo_servicio_internet</td>
#       <td id="T_0dd03_row1_col1" class="data row1 col1" >Fibra optica vs dsl</td>
#       <td id="T_0dd03_row1_col2" class="data row1 col2" >22.93 pp</td>
#       <td id="T_0dd03_row1_col3" class="data row1 col3" >120.96%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row2_col0" class="data row2 col0" >Tipo_contrato</td>
#       <td id="T_0dd03_row2_col1" class="data row2 col1" >Mes a Mes vs 1 año</td>
#       <td id="T_0dd03_row2_col2" class="data row2 col2" >31.44 pp</td>
#       <td id="T_0dd03_row2_col3" class="data row2 col3" >278.98%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row3_col0" class="data row3 col0" >Tipo_contrato</td>
#       <td id="T_0dd03_row3_col1" class="data row3 col1" >Mes a Mes vs 2 años</td>
#       <td id="T_0dd03_row3_col2" class="data row3 col2" >39.88 pp</td>
#       <td id="T_0dd03_row3_col3" class="data row3 col3" >1408.19%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row4_col0" class="data row4 col0" >Forma_pago</td>
#       <td id="T_0dd03_row4_col1" class="data row4 col1" >E-cheq vs Mailed check</td>
#       <td id="T_0dd03_row4_col2" class="data row4 col2" >26.18 pp</td>
#       <td id="T_0dd03_row4_col3" class="data row4 col3" >137.01%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row5_col0" class="data row5 col0" >Forma_pago</td>
#       <td id="T_0dd03_row5_col1" class="data row5 col1" >E-cheq vs bank transfer</td>
#       <td id="T_0dd03_row5_col2" class="data row5 col2" >28.58 pp</td>
#       <td id="T_0dd03_row5_col3" class="data row5 col3" >171.01%</td>
#     </tr>
#     <tr>
#       <td id="T_0dd03_row6_col0" class="data row6 col0" >Forma_pago</td>
#       <td id="T_0dd03_row6_col1" class="data row6 col1" >E-cheq vs credit card</td>
#       <td id="T_0dd03_row6_col2" class="data row6 col2" >30.04 pp</td>
#       <td id="T_0dd03_row6_col3" class="data row6 col3" >197.09%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tasas de abandono por servicios

# %%
col_servicios = ['Servicio_telefonico', 'Varias_lineas', 'Servicio_internet', 'Seguridad_en_linea', 'Copia_seguridad_en_linea', 'Proteccion_dispositivo', 'Soporte_tecnico', 'Televisión_por_cable', 'Streaming_peliculas']

# %%
col_servicios
# Out:
# ['Servicio_telefonico',
#  'Varias_lineas',
#  'Servicio_internet',
#  'Seguridad_en_linea',
#  'Copia_seguridad_en_linea',
#  'Proteccion_dispositivo',
#  'Soporte_tecnico',
#  'Televisión_por_cable',
#  'Streaming_peliculas']

# %%
fig, ax = plt.subplots(5,2, figsize=(18,12))
fig.suptitle('Tasas de abandonos por servicios', fontsize=16)
fig.subplots_adjust(wspace=0.15, hspace=0.55)

ax = ax.flatten()

for i, col in enumerate(col_servicios):
  promedio = df.groupby(col)['Abandono'].mean()

  bars = ax[i].bar(promedio.index, promedio.values)

  for bar in bars:
    altura = bar.get_height()
    ax[i].text(
        bar.get_x() + bar.get_width() / 2,
        altura,
        f'{altura*100:.1f}%',
        ha='center', va='bottom',
        fontsize=9
    )

  max_val = promedio.values.max()
  ax[i].set_ylim(0, max_val * 1.15)

  ax[i].set_title(f'Tasa de abandono por {col}')

  ax[i].set_xticks([0, 1])
  ax[i].set_xticklabels(['No', 'Si'])

  ax[i].set_ylabel('Tasa de abandono')
  ax[i].set_xlabel('¿Servicio contratado?')

fig.delaxes(ax[-1])

plt.show()

# %% [markdown]
# ## Tabla resumen por servicios

# %%
resumen_servicios = {}
for col in col_servicios:
  resumen_servicios[col] = df.groupby(col)['Abandono'].agg(
    clientes='count',
    abandonos='sum',
    tasa_abandono='mean'
  )

for i in col_servicios:
  resumen_servicios[i].rename(index={0: 'No', 1: 'Si'}, inplace=True)

df_servicios_resumen = (
    pd.concat(resumen_servicios, names=['Servicio', 'Incluido en el plan'])
      .reset_index()
)

estilo_resumen_servicios = (df_servicios_resumen
                            .sort_values('tasa_abandono', ascending=False)
                            .style
                            .format({'tasa_abandono':'{:.1%}'})
                            .background_gradient(subset=['tasa_abandono'], cmap='Reds')
                            .hide(axis='index'))


estilo_resumen_servicios
# Out:
# <style type="text/css">
# #T_d7829_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d7829_row1_col4 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_d7829_row2_col4 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_d7829_row3_col4 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_d7829_row4_col4 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_d7829_row5_col4 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_d7829_row6_col4, #T_d7829_row7_col4 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_d7829_row8_col4 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_d7829_row9_col4 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_d7829_row10_col4 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_d7829_row11_col4, #T_d7829_row12_col4 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_d7829_row13_col4 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_d7829_row14_col4 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_d7829_row15_col4 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_d7829_row16_col4 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_d7829_row17_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d7829" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_d7829_level0_col0" class="col_heading level0 col0" >Servicio</th>
#       <th id="T_d7829_level0_col1" class="col_heading level0 col1" >Incluido en el plan</th>
#       <th id="T_d7829_level0_col2" class="col_heading level0 col2" >clientes</th>
#       <th id="T_d7829_level0_col3" class="col_heading level0 col3" >abandonos</th>
#       <th id="T_d7829_level0_col4" class="col_heading level0 col4" >tasa_abandono</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d7829_row0_col0" class="data row0 col0" >Servicio_internet</td>
#       <td id="T_d7829_row0_col1" class="data row0 col1" >Si</td>
#       <td id="T_d7829_row0_col2" class="data row0 col2" >5517</td>
#       <td id="T_d7829_row0_col3" class="data row0 col3" >1756</td>
#       <td id="T_d7829_row0_col4" class="data row0 col4" >31.8%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row1_col0" class="data row1 col0" >Seguridad_en_linea</td>
#       <td id="T_d7829_row1_col1" class="data row1 col1" >No</td>
#       <td id="T_d7829_row1_col2" class="data row1 col2" >5024</td>
#       <td id="T_d7829_row1_col3" class="data row1 col3" >1574</td>
#       <td id="T_d7829_row1_col4" class="data row1 col4" >31.3%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row2_col0" class="data row2 col0" >Soporte_tecnico</td>
#       <td id="T_d7829_row2_col1" class="data row2 col1" >No</td>
#       <td id="T_d7829_row2_col2" class="data row2 col2" >4999</td>
#       <td id="T_d7829_row2_col3" class="data row2 col3" >1559</td>
#       <td id="T_d7829_row2_col4" class="data row2 col4" >31.2%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row3_col0" class="data row3 col0" >Televisión_por_cable</td>
#       <td id="T_d7829_row3_col1" class="data row3 col1" >Si</td>
#       <td id="T_d7829_row3_col2" class="data row3 col2" >2707</td>
#       <td id="T_d7829_row3_col3" class="data row3 col3" >814</td>
#       <td id="T_d7829_row3_col4" class="data row3 col4" >30.1%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row4_col0" class="data row4 col0" >Streaming_peliculas</td>
#       <td id="T_d7829_row4_col1" class="data row4 col1" >Si</td>
#       <td id="T_d7829_row4_col2" class="data row4 col2" >2732</td>
#       <td id="T_d7829_row4_col3" class="data row4 col3" >818</td>
#       <td id="T_d7829_row4_col4" class="data row4 col4" >29.9%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row5_col0" class="data row5 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_d7829_row5_col1" class="data row5 col1" >No</td>
#       <td id="T_d7829_row5_col2" class="data row5 col2" >4614</td>
#       <td id="T_d7829_row5_col3" class="data row5 col3" >1346</td>
#       <td id="T_d7829_row5_col4" class="data row5 col4" >29.2%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row6_col0" class="data row6 col0" >Proteccion_dispositivo</td>
#       <td id="T_d7829_row6_col1" class="data row6 col1" >No</td>
#       <td id="T_d7829_row6_col2" class="data row6 col2" >4621</td>
#       <td id="T_d7829_row6_col3" class="data row6 col3" >1324</td>
#       <td id="T_d7829_row6_col4" class="data row6 col4" >28.7%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row7_col0" class="data row7 col0" >Varias_lineas</td>
#       <td id="T_d7829_row7_col1" class="data row7 col1" >Si</td>
#       <td id="T_d7829_row7_col2" class="data row7 col2" >2971</td>
#       <td id="T_d7829_row7_col3" class="data row7 col3" >850</td>
#       <td id="T_d7829_row7_col4" class="data row7 col4" >28.6%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row8_col0" class="data row8 col0" >Servicio_telefonico</td>
#       <td id="T_d7829_row8_col1" class="data row8 col1" >Si</td>
#       <td id="T_d7829_row8_col2" class="data row8 col2" >6361</td>
#       <td id="T_d7829_row8_col3" class="data row8 col3" >1699</td>
#       <td id="T_d7829_row8_col4" class="data row8 col4" >26.7%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row9_col0" class="data row9 col0" >Varias_lineas</td>
#       <td id="T_d7829_row9_col1" class="data row9 col1" >No</td>
#       <td id="T_d7829_row9_col2" class="data row9 col2" >4072</td>
#       <td id="T_d7829_row9_col3" class="data row9 col3" >1019</td>
#       <td id="T_d7829_row9_col4" class="data row9 col4" >25.0%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row10_col0" class="data row10 col0" >Servicio_telefonico</td>
#       <td id="T_d7829_row10_col1" class="data row10 col1" >No</td>
#       <td id="T_d7829_row10_col2" class="data row10 col2" >682</td>
#       <td id="T_d7829_row10_col3" class="data row10 col3" >170</td>
#       <td id="T_d7829_row10_col4" class="data row10 col4" >24.9%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row11_col0" class="data row11 col0" >Streaming_peliculas</td>
#       <td id="T_d7829_row11_col1" class="data row11 col1" >No</td>
#       <td id="T_d7829_row11_col2" class="data row11 col2" >4311</td>
#       <td id="T_d7829_row11_col3" class="data row11 col3" >1051</td>
#       <td id="T_d7829_row11_col4" class="data row11 col4" >24.4%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row12_col0" class="data row12 col0" >Televisión_por_cable</td>
#       <td id="T_d7829_row12_col1" class="data row12 col1" >No</td>
#       <td id="T_d7829_row12_col2" class="data row12 col2" >4336</td>
#       <td id="T_d7829_row12_col3" class="data row12 col3" >1055</td>
#       <td id="T_d7829_row12_col4" class="data row12 col4" >24.3%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row13_col0" class="data row13 col0" >Proteccion_dispositivo</td>
#       <td id="T_d7829_row13_col1" class="data row13 col1" >Si</td>
#       <td id="T_d7829_row13_col2" class="data row13 col2" >2422</td>
#       <td id="T_d7829_row13_col3" class="data row13 col3" >545</td>
#       <td id="T_d7829_row13_col4" class="data row13 col4" >22.5%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row14_col0" class="data row14 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_d7829_row14_col1" class="data row14 col1" >Si</td>
#       <td id="T_d7829_row14_col2" class="data row14 col2" >2429</td>
#       <td id="T_d7829_row14_col3" class="data row14 col3" >523</td>
#       <td id="T_d7829_row14_col4" class="data row14 col4" >21.5%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row15_col0" class="data row15 col0" >Soporte_tecnico</td>
#       <td id="T_d7829_row15_col1" class="data row15 col1" >Si</td>
#       <td id="T_d7829_row15_col2" class="data row15 col2" >2044</td>
#       <td id="T_d7829_row15_col3" class="data row15 col3" >310</td>
#       <td id="T_d7829_row15_col4" class="data row15 col4" >15.2%</td>
#     </tr>
#     <tr>
#       <td id="T_d7829_row16_col0" class="data row16 col0" >Seguridad_en_linea</td>
#       <td id="T_d7829_row16_col1" class="data row16 col1" >Si</td>
#       <td id="T_d7829_row16_col2" class="data row16 col2" >2019</td>
#       <td id="T_d7829_row16_col3" class="data row16 col3" >295</td>
#       <td id="T_d7829_row16_col4" class="data row16

# %% [markdown]
# ## Principales diferencias de tasas de abandono entre los valores del mismo servicio

# %%
diferencia_tasa_servicios = {
    'Categoria' : ['Servicio_internet', 'Seguridad_en_linea', 'Soporte_tecnico'],
    'Valor' : ['Si', 'Si', 'Si'],
    'Diferencia absoluta' : [(df_servicios_resumen.loc[5, 'tasa_abandono'] - df_servicios_resumen.loc[4, 'tasa_abandono'])*100,
                             (df_servicios_resumen.loc[7, 'tasa_abandono'] - df_servicios_resumen.loc[6, 'tasa_abandono'])*100,
                             (df_servicios_resumen.loc[13, 'tasa_abandono'] - df_servicios_resumen.loc[12, 'tasa_abandono'])*100
                             ],
    'Riesgo Relativo' : [((df_servicios_resumen.loc[5, 'tasa_abandono'] / df_servicios_resumen.loc[4, 'tasa_abandono'])-1)*100,
                         ((df_servicios_resumen.loc[7, 'tasa_abandono'] / df_servicios_resumen.loc[6, 'tasa_abandono'])-1)*100,
                         ((df_servicios_resumen.loc[13, 'tasa_abandono'] / df_servicios_resumen.loc[12, 'tasa_abandono'])-1)*100
                             ],
}

df_diferencia_tasa_servicios = pd.DataFrame(diferencia_tasa_servicios)
df_diferencia_tasa_servicios.style.format({'Diferencia absoluta' : '{:.2f} pp',
                                                'Riesgo Relativo' : '{:.2f}%'}).highlight_between(left=-100, right=500, subset=['Riesgo Relativo'], color='skyBlue').hide(axis='index')
# Out:
# <style type="text/css">
# #T_dea6c_row0_col3, #T_dea6c_row1_col3, #T_dea6c_row2_col3 {
#   background-color: skyBlue;
# }
# </style>
# <table id="T_dea6c" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_dea6c_level0_col0" class="col_heading level0 col0" >Categoria</th>
#       <th id="T_dea6c_level0_col1" class="col_heading level0 col1" >Valor</th>
#       <th id="T_dea6c_level0_col2" class="col_heading level0 col2" >Diferencia absoluta</th>
#       <th id="T_dea6c_level0_col3" class="col_heading level0 col3" >Riesgo Relativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dea6c_row0_col0" class="data row0 col0" >Servicio_internet</td>
#       <td id="T_dea6c_row0_col1" class="data row0 col1" >Si</td>
#       <td id="T_dea6c_row0_col2" class="data row0 col2" >24.42 pp</td>
#       <td id="T_dea6c_row0_col3" class="data row0 col3" >329.83%</td>
#     </tr>
#     <tr>
#       <td id="T_dea6c_row1_col0" class="data row1 col0" >Seguridad_en_linea</td>
#       <td id="T_dea6c_row1_col1" class="data row1 col1" >Si</td>
#       <td id="T_dea6c_row1_col2" class="data row1 col2" >-16.72 pp</td>
#       <td id="T_dea6c_row1_col3" class="data row1 col3" >-53.36%</td>
#     </tr>
#     <tr>
#       <td id="T_dea6c_row2_col0" class="data row2 col0" >Soporte_tecnico</td>
#       <td id="T_dea6c_row2_col1" class="data row2 col1" >Si</td>
#       <td id="T_dea6c_row2_col2" class="data row2 col2" >-16.02 pp</td>
#       <td id="T_dea6c_row2_col3" class="data row2 col3" >-51.37%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Distribución de variables numéricas

# %%
# Creamos una columna que cuenta la cantidad de servicios contratados por cliente
df['N_servicios']  = df[col_servicios].sum(axis=1)
df.head(2)
# Out:
#    Cliente_ID  Abandono  Genero  Ciudadano_mayor  Pareja  Dependientes  \
# 0  0002-ORFBO         0       1                0       1             1
# 1  0003-MKNFE         0       0                0       0             0
#
#    Meses_permanencia  Servicio_telefonico  Varias_lineas  Servicio_internet  \
# 0                  9                    1              0                  1
# 1                  9                    1              1                  1
#
#   Tipo_servicio_internet  Seguridad_en_linea  Copia_seguridad_en_linea  \
# 0                    dsl                   0                         1
# 1                    dsl                   0                         0
#
#    Proteccion_dispositivo  Soporte_tecnico  Televisión_por_cable  \
# 0                       0                1                     1
# 1                       0                0                     0
#
#    Streaming_peliculas   Tipo_contrato  Factura_en_linea    Forma_pago  \
# 0                    0        one year                 1  mailed check
# 1                    1  month-to-month                 0  mailed check
#
#    Cuentas_diarias  Cuenta_mensual  Cargo_total  N_servicios
# 0         2.186667            65.6        593.3            5
# 1         1.996667            59.9        542.4            4

# %%
fig, ax = plt.subplots(3,2, figsize=(15,8))
fig.suptitle('Distribución de variables numéricas según abandono del cliente', fontsize=18)
fig.subplots_adjust(wspace=0.15, hspace=0.45)
columnas_numericas = ['Meses_permanencia', 'Cuentas_diarias', 'Cuenta_mensual', 'Cargo_total', 'N_servicios']

ax = ax.flatten()

for i, col in enumerate(columnas_numericas):
  sns.boxplot(data=df, x='Abandono', y=col, ax=ax[i], flierprops=dict(marker='o', markerfacecolor='red', markeredgecolor='black', markersize=5, alpha=0.7))
  ax[i].set_title(f'{col} vs Abandono')
  ax[i].set_xlabel('Estado de Abandono')
  ax[i].set_xticks([0,1])
  ax[i].set_xticklabels(['No Abandonó', 'Abandonó'])

fig.delaxes(ax[-1])
plt.show()

# %% [markdown]
# ## Tabla resumen por columnas númericas

# %% [markdown]
# ## Clientes que continúan en la empresa

# %%
df.loc[df['Abandono'] == 0, columnas_numericas].describe()
# Out:
#        Meses_permanencia  Cuentas_diarias  Cuenta_mensual  Cargo_total  \
# count        5174.000000      5174.000000     5174.000000  5174.000000
# mean           37.569965         2.042171       61.265124  2549.999497
# std            24.113777         1.036422       31.092648  2329.858843
# min             0.000000         0.608333       18.250000    18.800000
# 25%            15.000000         0.836667       25.100000   572.900000
# 50%            38.000000         2.147500       64.425000  1679.525000
# 75%            61.000000         2.946667       88.400000  4262.850000
# max            72.000000         3.958333      118.750000  8672.450000
#
#        N_servicios
# count       5174.0
# mean      4.173174
# std       2.461018
# min            1.0
# 25%            2.0
# 50%            4.0
# 75%            6.0
# max            9.0

# %% [markdown]
# ## Clientes que abandonaron la empresa

# %%
df.loc[df['Abandono'] == 1, columnas_numericas].describe()
# Out:
#        Meses_permanencia  Cuentas_diarias  Cuenta_mensual  Cargo_total  \
# count        1869.000000      1869.000000     1869.000000  1869.000000
# mean           17.979133         2.481378       74.441332  1531.796094
# std            19.531123         0.822202       24.666053  1890.822994
# min             1.000000         0.628333       18.850000    18.850000
# 25%             2.000000         1.871667       56.150000   134.500000
# 50%            10.000000         2.655000       79.650000   703.550000
# 75%            29.000000         3.140000       94.200000  2331.300000
# max            72.000000         3.945000      118.350000  8684.800000
#
#        N_servicios
# count       1869.0
# mean      4.071696
# std       1.839431
# min            1.0
# 25%            3.0
# 50%            4.0
# 75%            5.0
# max            9.0

# %% [markdown]
# ## Analisis Outliers Cargo_total vs Abandono

# %%
df_cliente_abandono= df[df['Abandono'] == 1]
df_cliente_abandono.head(2)
# Out:
#    Cliente_ID  Abandono  Genero  Ciudadano_mayor  Pareja  Dependientes  \
# 2  0004-TLHLJ         1       0                0       0             0
# 3  0011-IGKFF         1       0                1       1             0
#
#    Meses_permanencia  Servicio_telefonico  Varias_lineas  Servicio_internet  \
# 2                  4                    1              0                  1
# 3                 13                    1              0                  1
#
#   Tipo_servicio_internet  Seguridad_en_linea  Copia_seguridad_en_linea  \
# 2            fiber optic                   0                         0
# 3            fiber optic                   0                         1
#
#    Proteccion_dispositivo  Soporte_tecnico  Televisión_por_cable  \
# 2                       1                0                     0
# 3                       1                0                     1
#
#    Streaming_peliculas   Tipo_contrato  Factura_en_linea        Forma_pago  \
# 2                    0  month-to-month                 1  electronic check
# 3                    1  month-to-month                 1  electronic check
#
#    Cuentas_diarias  Cuenta_mensual  Cargo_total  N_servicios
# 2         2.463333            73.9       280.85            3
# 3         3.266667            98.0      1237.85            6

# %%
Q1 = df_cliente_abandono['Cargo_total'].quantile(0.25)
Q3 = df_cliente_abandono['Cargo_total'].quantile(0.75)
IQR = Q3 - Q1

limite_superior = Q3 + 1.5 * IQR

# %%
outliers_cargo_total = df_cliente_abandono[df_cliente_abandono['Cargo_total'] > limite_superior]

# %%
cantidad_outliers = len(outliers_cargo_total)
cantidad_outliers
# Out:
# 109

# %%
resto_cargo_total = df_cliente_abandono[df_cliente_abandono['Cargo_total'] <= limite_superior]
cantidad_no_outliers = len(resto_cargo_total)
cantidad_no_outliers
# Out:
# 1760

# %%
comparacion_cargo_total = pd.DataFrame({
    'Outliers (%)' : outliers_cargo_total[columnas_numericas].mean(),
    'Resto (%)' : resto_cargo_total[columnas_numericas].mean()
})

estilo_comparacion_cargo_total = comparacion_cargo_total.T.style.format({
    'Meses_permanencia' : '{:,.0f}',
    'N_servicios' : '{:,.0f}',
    'Cuentas_diarias' : '{:,.2f}',
    'Cuenta_mensual' : '{:,.2f}',
    'Cargo_total': '{:,.2f}'})
estilo_comparacion_cargo_total
# Out:
# <style type="text/css">
# </style>
# <table id="T_23399" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23399_level0_col0" class="col_heading level0 col0" >Meses_permanencia</th>
#       <th id="T_23399_level0_col1" class="col_heading level0 col1" >Cuentas_diarias</th>
#       <th id="T_23399_level0_col2" class="col_heading level0 col2" >Cuenta_mensual</th>
#       <th id="T_23399_level0_col3" class="col_heading level0 col3" >Cargo_total</th>
#       <th id="T_23399_level0_col4" class="col_heading level0 col4" >N_servicios</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23399_level0_row0" class="row_heading level0 row0" >Outliers (%)</th>
#       <td id="T_23399_row0_col0" class="data row0 col0" >64</td>
#       <td id="T_23399_row0_col1" class="data row0 col1" >3.47</td>
#       <td id="T_23399_row0_col2" class="data row0 col2" >104.15</td>
#       <td id="T_23399_row0_col3" class="data row0 col3" >6,670.28</td>
#       <td id="T_23399_row0_col4" class="data row0 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_23399_level0_row1" class="row_heading level0 row1" >Resto (%)</th>
#       <td id="T_23399_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_23399_row1_col1" class="data row1 col1" >2.42</td>
#       <td id="T_23399_row1_col2" class="data row1 col2" >72.60</td>
#       <td id="T_23399_row1_col3" class="data row1 col3" >1,213.56</td>
#       <td id="T_23399_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Matriz de correlación entre las variables

# %%
df_corr_col_numericas = df.corr(numeric_only=True)

# %%
mascara = np.triu(np.ones_like(df_corr_col_numericas, dtype=bool))

mascara_col_restantes = np.ones_like(df_corr_col_numericas, dtype=bool)
mascara_col_restantes[:,0] = False

mascara_final = mascara | mascara_col_restantes

# %%
plt.figure(figsize=(20,8))
plt.title('Correlación entre las variables', fontsize=16)
sns.heatmap(data=df_corr_col_numericas, mask=mascara, cmap='Greys', annot=True, fmt='.1f', center=0)

sns.heatmap(data=df_corr_col_numericas, mask=mascara_final, cmap='coolwarm', annot=True, fmt='.1f', center=0)

plt.xticks(rotation=-90)
plt.show()

plt.show()

# %% [markdown]
# # Perfil del cliente que abandonó la empresa

# %% [markdown]
# ## Distribución por variables categóricas:

# %%
descripcion_abandono_cat = []
for col in lista_columnas_categoricas:
  tabla = df_cliente_abandono[col].value_counts(normalize=True).mul(100).reset_index()
  tabla.columns = ['valor', '% de clientes']
  tabla.insert(0, 'categoria', col)
  descripcion_abandono_cat.append(tabla)

descripcion_general_abandono_cat = pd.concat(descripcion_abandono_cat, ignore_index=True)
descripcion_general_abandono_cat.loc[descripcion_general_abandono_cat['categoria'] == 'Genero', 'valor'] = descripcion_general_abandono_cat.loc[descripcion_general_abandono_cat['categoria'] == 'Genero', 'valor'].replace({0:'Male', 1:'Female'})
descripcion_general_abandono_cat['valor'] = descripcion_general_abandono_cat['valor'].replace({0 : 'No', 1 : 'Si'})
descripcion_general_abandono_cat.style.format({'% de clientes' : '{:.2f}%'}).hide(axis='index').highlight_between(left=55, right=100, subset=['% de clientes'], color='Red')
# Out:
# <style type="text/css">
# #T_0a607_row2_col2, #T_0a607_row4_col2, #T_0a607_row6_col2, #T_0a607_row8_col2, #T_0a607_row11_col2, #T_0a607_row14_col2 {
#   background-color: Red;
# }
# </style>
# <table id="T_0a607" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_0a607_level0_col0" class="col_heading level0 col0" >categoria</th>
#       <th id="T_0a607_level0_col1" class="col_heading level0 col1" >valor</th>
#       <th id="T_0a607_level0_col2" class="col_heading level0 col2" >% de clientes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a607_row0_col0" class="data row0 col0" >Genero</td>
#       <td id="T_0a607_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_0a607_row0_col2" class="data row0 col2" >50.24%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row1_col0" class="data row1 col0" >Genero</td>
#       <td id="T_0a607_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_0a607_row1_col2" class="data row1 col2" >49.76%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row2_col0" class="data row2 col0" >Ciudadano_mayor</td>
#       <td id="T_0a607_row2_col1" class="data row2 col1" >No</td>
#       <td id="T_0a607_row2_col2" class="data row2 col2" >74.53%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row3_col0" class="data row3 col0" >Ciudadano_mayor</td>
#       <td id="T_0a607_row3_col1" class="data row3 col1" >Si</td>
#       <td id="T_0a607_row3_col2" class="data row3 col2" >25.47%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row4_col0" class="data row4 col0" >Pareja</td>
#       <td id="T_0a607_row4_col1" class="data row4 col1" >No</td>
#       <td id="T_0a607_row4_col2" class="data row4 col2" >64.21%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row5_col0" class="data row5 col0" >Pareja</td>
#       <td id="T_0a607_row5_col1" class="data row5 col1" >Si</td>
#       <td id="T_0a607_row5_col2" class="data row5 col2" >35.79%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row6_col0" class="data row6 col0" >Dependientes</td>
#       <td id="T_0a607_row6_col1" class="data row6 col1" >No</td>
#       <td id="T_0a607_row6_col2" class="data row6 col2" >82.56%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row7_col0" class="data row7 col0" >Dependientes</td>
#       <td id="T_0a607_row7_col1" class="data row7 col1" >Si</td>
#       <td id="T_0a607_row7_col2" class="data row7 col2" >17.44%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row8_col0" class="data row8 col0" >Tipo_servicio_internet</td>
#       <td id="T_0a607_row8_col1" class="data row8 col1" >fiber optic</td>
#       <td id="T_0a607_row8_col2" class="data row8 col2" >69.40%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row9_col0" class="data row9 col0" >Tipo_servicio_internet</td>
#       <td id="T_0a607_row9_col1" class="data row9 col1" >dsl</td>
#       <td id="T_0a607_row9_col2" class="data row9 col2" >24.56%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row10_col0" class="data row10 col0" >Tipo_servicio_internet</td>
#       <td id="T_0a607_row10_col1" class="data row10 col1" >no internet service</td>
#       <td id="T_0a607_row10_col2" class="data row10 col2" >6.05%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row11_col0" class="data row11 col0" >Tipo_contrato</td>
#       <td id="T_0a607_row11_col1" class="data row11 col1" >month-to-month</td>
#       <td id="T_0a607_row11_col2" class="data row11 col2" >88.55%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row12_col0" class="data row12 col0" >Tipo_contrato</td>
#       <td id="T_0a607_row12_col1" class="data row12 col1" >one year</td>
#       <td id="T_0a607_row12_col2" class="data row12 col2" >8.88%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row13_col0" class="data row13 col0" >Tipo_contrato</td>
#       <td id="T_0a607_row13_col1" class="data row13 col1" >two year</td>
#       <td id="T_0a607_row13_col2" class="data row13 col2" >2.57%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row14_col0" class="data row14 col0" >Forma_pago</td>
#       <td id="T_0a607_row14_col1" class="data row14 col1" >electronic check</td>
#       <td id="T_0a607_row14_col2" class="data row14 col2" >57.30%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row15_col0" class="data row15 col0" >Forma_pago</td>
#       <td id="T_0a607_row15_col1" class="data row15 col1" >mailed check</td>
#       <td id="T_0a607_row15_col2" class="data row15 col2" >16.48%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row16_col0" class="data row16 col0" >Forma_pago</td>
#       <td id="T_0a607_row16_col1" class="data row16 col1" >bank transfer (automatic)</td>
#       <td id="T_0a607_row16_col2" class="data row16 col2" >13.80%</td>
#     </tr>
#     <tr>
#       <td id="T_0a607_row17_col0" class="data row17 col0" >Forma_pago</td>
#       <td id="T_0a607_row17_col1" class="data row17 col1" >credit card (automatic)</td>
#       <td id="T_0a607_row17_col2" class="data row17 col2" >12.41%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Distribución de servicios contratados:

# %%
descripcion_abandono_servicio = []
for col in col_servicios:
  tabla = df_cliente_abandono[col].value_counts(normalize=True).mul(100).reset_index()
  tabla.columns = ['valor', '% de clientes']
  tabla.insert(0, 'categoria', col)
  descripcion_abandono_servicio.append(tabla)

descripcion_general_abandono_serv = pd.concat(descripcion_abandono_servicio, ignore_index=True)
descripcion_general_abandono_serv['valor'] = descripcion_general_abandono_serv['valor'].astype('object').replace({0 : 'No', 1 : 'Si'})

descripcion_general_abandono_serv['valor'] = pd.Categorical(descripcion_general_abandono_serv['valor'], categories=['Si', 'No'], ordered=True)
descripcion_general_abandono_serv = descripcion_general_abandono_serv.sort_values(['categoria', 'valor'])
descripcion_general_abandono_serv.style.format({'% de clientes' : '{:.2f}%'}).hide(axis='index').highlight_between(left=70, right=100, subset=['% de clientes'], color='Red')
# Out:
# <style type="text/css">
# #T_3cfb4_row1_col2, #T_3cfb4_row3_col2, #T_3cfb4_row5_col2, #T_3cfb4_row6_col2, #T_3cfb4_row8_col2, #T_3cfb4_row11_col2 {
#   background-color: Red;
# }
# </style>
# <table id="T_3cfb4" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_3cfb4_level0_col0" class="col_heading level0 col0" >categoria</th>
#       <th id="T_3cfb4_level0_col1" class="col_heading level0 col1" >valor</th>
#       <th id="T_3cfb4_level0_col2" class="col_heading level0 col2" >% de clientes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3cfb4_row0_col0" class="data row0 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_3cfb4_row0_col1" class="data row0 col1" >Si</td>
#       <td id="T_3cfb4_row0_col2" class="data row0 col2" >27.98%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row1_col0" class="data row1 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_3cfb4_row1_col1" class="data row1 col1" >No</td>
#       <td id="T_3cfb4_row1_col2" class="data row1 col2" >72.02%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row2_col0" class="data row2 col0" >Proteccion_dispositivo</td>
#       <td id="T_3cfb4_row2_col1" class="data row2 col1" >Si</td>
#       <td id="T_3cfb4_row2_col2" class="data row2 col2" >29.16%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row3_col0" class="data row3 col0" >Proteccion_dispositivo</td>
#       <td id="T_3cfb4_row3_col1" class="data row3 col1" >No</td>
#       <td id="T_3cfb4_row3_col2" class="data row3 col2" >70.84%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row4_col0" class="data row4 col0" >Seguridad_en_linea</td>
#       <td id="T_3cfb4_row4_col1" class="data row4 col1" >Si</td>
#       <td id="T_3cfb4_row4_col2" class="data row4 col2" >15.78%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row5_col0" class="data row5 col0" >Seguridad_en_linea</td>
#       <td id="T_3cfb4_row5_col1" class="data row5 col1" >No</td>
#       <td id="T_3cfb4_row5_col2" class="data row5 col2" >84.22%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row6_col0" class="data row6 col0" >Servicio_internet</td>
#       <td id="T_3cfb4_row6_col1" class="data row6 col1" >Si</td>
#       <td id="T_3cfb4_row6_col2" class="data row6 col2" >93.95%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row7_col0" class="data row7 col0" >Servicio_internet</td>
#       <td id="T_3cfb4_row7_col1" class="data row7 col1" >No</td>
#       <td id="T_3cfb4_row7_col2" class="data row7 col2" >6.05%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row8_col0" class="data row8 col0" >Servicio_telefonico</td>
#       <td id="T_3cfb4_row8_col1" class="data row8 col1" >Si</td>
#       <td id="T_3cfb4_row8_col2" class="data row8 col2" >90.90%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row9_col0" class="data row9 col0" >Servicio_telefonico</td>
#       <td id="T_3cfb4_row9_col1" class="data row9 col1" >No</td>
#       <td id="T_3cfb4_row9_col2" class="data row9 col2" >9.10%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row10_col0" class="data row10 col0" >Soporte_tecnico</td>
#       <td id="T_3cfb4_row10_col1" class="data row10 col1" >Si</td>
#       <td id="T_3cfb4_row10_col2" class="data row10 col2" >16.59%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row11_col0" class="data row11 col0" >Soporte_tecnico</td>
#       <td id="T_3cfb4_row11_col1" class="data row11 col1" >No</td>
#       <td id="T_3cfb4_row11_col2" class="data row11 col2" >83.41%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row12_col0" class="data row12 col0" >Streaming_peliculas</td>
#       <td id="T_3cfb4_row12_col1" class="data row12 col1" >Si</td>
#       <td id="T_3cfb4_row12_col2" class="data row12 col2" >43.77%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row13_col0" class="data row13 col0" >Streaming_peliculas</td>
#       <td id="T_3cfb4_row13_col1" class="data row13 col1" >No</td>
#       <td id="T_3cfb4_row13_col2" class="data row13 col2" >56.23%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row14_col0" class="data row14 col0" >Televisión_por_cable</td>
#       <td id="T_3cfb4_row14_col1" class="data row14 col1" >Si</td>
#       <td id="T_3cfb4_row14_col2" class="data row14 col2" >43.55%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row15_col0" class="data row15 col0" >Televisión_por_cable</td>
#       <td id="T_3cfb4_row15_col1" class="data row15 col1" >No</td>
#       <td id="T_3cfb4_row15_col2" class="data row15 col2" >56.45%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row16_col0" class="data row16 col0" >Varias_lineas</td>
#       <td id="T_3cfb4_row16_col1" class="data row16 col1" >Si</td>
#       <td id="T_3cfb4_row16_col2" class="data row16 col2" >45.48%</td>
#     </tr>
#     <tr>
#       <td id="T_3cfb4_row17_col0" class="data row17 col0" >Varias_lineas</td>
#       <td id="T_3cfb4_row17_col1" class="data row17 col1" >No</td>
#       <td id="T_3cfb4_row17_col2" class="data row17 col2" >54.52%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Distribución de variables numéricas:

# %%
fig, ax = plt.subplots(3,2, figsize=(14,16))
fig.subplots_adjust(hspace=0.2)
fig.suptitle('Distribución de variables numéricas: Cliente Abandono', fontsize=16)
ax = ax.flatten()
for i,col in enumerate(columnas_numericas):
  counts, bins, patches = ax[i].hist(
    df_cliente_abandono[col],
    bins=9)

  ax[i].set_title(f'Distribución de clientes que abandonaron por {col}')
  ax[i].set_xlabel(f'{col}')
  ax[i].set_ylabel('Cantidad de clientes')

  count_suma = 0
  for count, patch in zip(counts, patches):
    count_suma += count
    if count > 0:
      ax[i].text(
          patch.get_x() + patch.get_width() / 2,
          count,
          f'{count_suma/len(df_cliente_abandono) * 100:.2f}%',
          ha='center',
          va='bottom',
          fontsize=8
      )

fig.delaxes(ax[-1])
plt.show()

# %% [markdown]
# ## Perfil del cliente que continúa en la empresa

# %% [markdown]
# ## Distribución por variables categóricas:

# %%
df_cliente_no_abandono = df[df['Abandono'] == 0]

# %%
descrip_no_abandono_cat = []
for col in lista_columnas_categoricas:
  tabla = df_cliente_no_abandono[col].value_counts(normalize=True).mul(100).reset_index()
  tabla.columns = ['valor', '% de clientes']
  tabla.insert(0, 'categoria', col)
  descrip_no_abandono_cat.append(tabla)

descripcion_general_no_abandono_cat = pd.concat(descrip_no_abandono_cat, ignore_index=True)
descripcion_general_no_abandono_cat.loc[descripcion_general_no_abandono_cat['categoria'] == 'Genero', 'valor'] = descripcion_general_no_abandono_cat.loc[descripcion_general_no_abandono_cat['categoria'] == 'Genero', 'valor'].replace({0:'Male', 1:'Female'})
descripcion_general_no_abandono_cat['valor'] = descripcion_general_no_abandono_cat['valor'].replace({0 : 'No', 1 : 'Si'})
descripcion_general_no_abandono_cat.style.format({'% de clientes' : '{:.2f}%'}).hide(axis='index').highlight_between(left=55, right=100, subset=['% de clientes'], color='Red')
# Out:
# <style type="text/css">
# #T_23411_row2_col2, #T_23411_row6_col2 {
#   background-color: Red;
# }
# </style>
# <table id="T_23411" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_23411_level0_col0" class="col_heading level0 col0" >categoria</th>
#       <th id="T_23411_level0_col1" class="col_heading level0 col1" >valor</th>
#       <th id="T_23411_level0_col2" class="col_heading level0 col2" >% de clientes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23411_row0_col0" class="data row0 col0" >Genero</td>
#       <td id="T_23411_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_23411_row0_col2" class="data row0 col2" >50.73%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row1_col0" class="data row1 col0" >Genero</td>
#       <td id="T_23411_row1_col1" class="data row1 col1" >Female</td>
#       <td id="T_23411_row1_col2" class="data row1 col2" >49.27%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row2_col0" class="data row2 col0" >Ciudadano_mayor</td>
#       <td id="T_23411_row2_col1" class="data row2 col1" >No</td>
#       <td id="T_23411_row2_col2" class="data row2 col2" >87.13%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row3_col0" class="data row3 col0" >Ciudadano_mayor</td>
#       <td id="T_23411_row3_col1" class="data row3 col1" >Si</td>
#       <td id="T_23411_row3_col2" class="data row3 col2" >12.87%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row4_col0" class="data row4 col0" >Pareja</td>
#       <td id="T_23411_row4_col1" class="data row4 col1" >Si</td>
#       <td id="T_23411_row4_col2" class="data row4 col2" >52.82%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row5_col0" class="data row5 col0" >Pareja</td>
#       <td id="T_23411_row5_col1" class="data row5 col1" >No</td>
#       <td id="T_23411_row5_col2" class="data row5 col2" >47.18%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row6_col0" class="data row6 col0" >Dependientes</td>
#       <td id="T_23411_row6_col1" class="data row6 col1" >No</td>
#       <td id="T_23411_row6_col2" class="data row6 col2" >65.52%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row7_col0" class="data row7 col0" >Dependientes</td>
#       <td id="T_23411_row7_col1" class="data row7 col1" >Si</td>
#       <td id="T_23411_row7_col2" class="data row7 col2" >34.48%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row8_col0" class="data row8 col0" >Tipo_servicio_internet</td>
#       <td id="T_23411_row8_col1" class="data row8 col1" >dsl</td>
#       <td id="T_23411_row8_col2" class="data row8 col2" >37.92%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row9_col0" class="data row9 col0" >Tipo_servicio_internet</td>
#       <td id="T_23411_row9_col1" class="data row9 col1" >fiber optic</td>
#       <td id="T_23411_row9_col2" class="data row9 col2" >34.77%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row10_col0" class="data row10 col0" >Tipo_servicio_internet</td>
#       <td id="T_23411_row10_col1" class="data row10 col1" >no internet service</td>
#       <td id="T_23411_row10_col2" class="data row10 col2" >27.31%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row11_col0" class="data row11 col0" >Tipo_contrato</td>
#       <td id="T_23411_row11_col1" class="data row11 col1" >month-to-month</td>
#       <td id="T_23411_row11_col2" class="data row11 col2" >42.91%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row12_col0" class="data row12 col0" >Tipo_contrato</td>
#       <td id="T_23411_row12_col1" class="data row12 col1" >two year</td>
#       <td id="T_23411_row12_col2" class="data row12 col2" >31.83%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row13_col0" class="data row13 col0" >Tipo_contrato</td>
#       <td id="T_23411_row13_col1" class="data row13 col1" >one year</td>
#       <td id="T_23411_row13_col2" class="data row13 col2" >25.26%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row14_col0" class="data row14 col0" >Forma_pago</td>
#       <td id="T_23411_row14_col1" class="data row14 col1" >mailed check</td>
#       <td id="T_23411_row14_col2" class="data row14 col2" >25.20%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row15_col0" class="data row15 col0" >Forma_pago</td>
#       <td id="T_23411_row15_col1" class="data row15 col1" >electronic check</td>
#       <td id="T_23411_row15_col2" class="data row15 col2" >25.01%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row16_col0" class="data row16 col0" >Forma_pago</td>
#       <td id="T_23411_row16_col1" class="data row16 col1" >credit card (automatic)</td>
#       <td id="T_23411_row16_col2" class="data row16 col2" >24.93%</td>
#     </tr>
#     <tr>
#       <td id="T_23411_row17_col0" class="data row17 col0" >Forma_pago</td>
#       <td id="T_23411_row17_col1" class="data row17 col1" >bank transfer (automatic)</td>
#       <td id="T_23411_row17_col2" class="data row17 col2" >24.86%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Distribución por servicios contratados:

# %%
descrip_no_abandono_serv = []
for col in col_servicios:
  tabla = df_cliente_no_abandono[col].value_counts(normalize=True).mul(100).reset_index()
  tabla.columns = ['valor', '% de clientes']
  tabla.insert(0, 'categoria', col)
  descrip_no_abandono_serv.append(tabla)

descrip_general_no_abandono_serv = pd.concat(descrip_no_abandono_serv, ignore_index=True)
descrip_general_no_abandono_serv['valor'] = descrip_general_no_abandono_serv['valor'].astype('object').replace({0 : 'No', 1 : 'Si'})

descrip_general_no_abandono_serv['valor'] = pd.Categorical(descrip_general_no_abandono_serv['valor'], categories=['Si', 'No'], ordered=True)
descrip_general_no_abandono_serv = descrip_general_no_abandono_serv.sort_values(['categoria', 'valor'])
descrip_general_no_abandono_serv.style.format({'% de clientes' : '{:.2f}%'}).hide(axis='index').highlight_between(left=70, right=100, subset=['% de clientes'], color='Red')
# Out:
# <style type="text/css">
# #T_e8fe1_row6_col2, #T_e8fe1_row8_col2 {
#   background-color: Red;
# }
# </style>
# <table id="T_e8fe1" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_e8fe1_level0_col0" class="col_heading level0 col0" >categoria</th>
#       <th id="T_e8fe1_level0_col1" class="col_heading level0 col1" >valor</th>
#       <th id="T_e8fe1_level0_col2" class="col_heading level0 col2" >% de clientes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e8fe1_row0_col0" class="data row0 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_e8fe1_row0_col1" class="data row0 col1" >Si</td>
#       <td id="T_e8fe1_row0_col2" class="data row0 col2" >36.84%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row1_col0" class="data row1 col0" >Copia_seguridad_en_linea</td>
#       <td id="T_e8fe1_row1_col1" class="data row1 col1" >No</td>
#       <td id="T_e8fe1_row1_col2" class="data row1 col2" >63.16%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row2_col0" class="data row2 col0" >Proteccion_dispositivo</td>
#       <td id="T_e8fe1_row2_col1" class="data row2 col1" >Si</td>
#       <td id="T_e8fe1_row2_col2" class="data row2 col2" >36.28%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row3_col0" class="data row3 col0" >Proteccion_dispositivo</td>
#       <td id="T_e8fe1_row3_col1" class="data row3 col1" >No</td>
#       <td id="T_e8fe1_row3_col2" class="data row3 col2" >63.72%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row4_col0" class="data row4 col0" >Seguridad_en_linea</td>
#       <td id="T_e8fe1_row4_col1" class="data row4 col1" >Si</td>
#       <td id="T_e8fe1_row4_col2" class="data row4 col2" >33.32%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row5_col0" class="data row5 col0" >Seguridad_en_linea</td>
#       <td id="T_e8fe1_row5_col1" class="data row5 col1" >No</td>
#       <td id="T_e8fe1_row5_col2" class="data row5 col2" >66.68%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row6_col0" class="data row6 col0" >Servicio_internet</td>
#       <td id="T_e8fe1_row6_col1" class="data row6 col1" >Si</td>
#       <td id="T_e8fe1_row6_col2" class="data row6 col2" >72.69%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row7_col0" class="data row7 col0" >Servicio_internet</td>
#       <td id="T_e8fe1_row7_col1" class="data row7 col1" >No</td>
#       <td id="T_e8fe1_row7_col2" class="data row7 col2" >27.31%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row8_col0" class="data row8 col0" >Servicio_telefonico</td>
#       <td id="T_e8fe1_row8_col1" class="data row8 col1" >Si</td>
#       <td id="T_e8fe1_row8_col2" class="data row8 col2" >90.10%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row9_col0" class="data row9 col0" >Servicio_telefonico</td>
#       <td id="T_e8fe1_row9_col1" class="data row9 col1" >No</td>
#       <td id="T_e8fe1_row9_col2" class="data row9 col2" >9.90%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row10_col0" class="data row10 col0" >Soporte_tecnico</td>
#       <td id="T_e8fe1_row10_col1" class="data row10 col1" >Si</td>
#       <td id="T_e8fe1_row10_col2" class="data row10 col2" >33.51%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row11_col0" class="data row11 col0" >Soporte_tecnico</td>
#       <td id="T_e8fe1_row11_col1" class="data row11 col1" >No</td>
#       <td id="T_e8fe1_row11_col2" class="data row11 col2" >66.49%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row12_col0" class="data row12 col0" >Streaming_peliculas</td>
#       <td id="T_e8fe1_row12_col1" class="data row12 col1" >Si</td>
#       <td id="T_e8fe1_row12_col2" class="data row12 col2" >36.99%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row13_col0" class="data row13 col0" >Streaming_peliculas</td>
#       <td id="T_e8fe1_row13_col1" class="data row13 col1" >No</td>
#       <td id="T_e8fe1_row13_col2" class="data row13 col2" >63.01%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row14_col0" class="data row14 col0" >Televisión_por_cable</td>
#       <td id="T_e8fe1_row14_col1" class="data row14 col1" >Si</td>
#       <td id="T_e8fe1_row14_col2" class="data row14 col2" >36.59%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row15_col0" class="data row15 col0" >Televisión_por_cable</td>
#       <td id="T_e8fe1_row15_col1" class="data row15 col1" >No</td>
#       <td id="T_e8fe1_row15_col2" class="data row15 col2" >63.41%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row16_col0" class="data row16 col0" >Varias_lineas</td>
#       <td id="T_e8fe1_row16_col1" class="data row16 col1" >Si</td>
#       <td id="T_e8fe1_row16_col2" class="data row16 col2" >40.99%</td>
#     </tr>
#     <tr>
#       <td id="T_e8fe1_row17_col0" class="data row17 col0" >Varias_lineas</td>
#       <td id="T_e8fe1_row17_col1" class="data row17 col1" >No</td>
#       <td id="T_e8fe1_row17_col2" class="data row17 col2" >59.01%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Distribución por variables numéricas:

# %%
fig, ax = plt.subplots(3,2, figsize=(14,16))
fig.subplots_adjust(hspace=0.2)
fig.suptitle('Distribución de variables numéricas: Cliente No Abandono', fontsize=16)
ax = ax.flatten()
for i,col in enumerate(columnas_numericas):
  counts, bins, patches = ax[i].hist(
    df_cliente_no_abandono[col],
    bins=9)

  ax[i].set_title(f'Distribución de clientes que permanecen por {col}')
  ax[i].set_xlabel(f'{col}')
  ax[i].set_ylabel('Cantidad de clientes')

  suma_count = 0
  for count, patch in zip(counts, patches):
    suma_count +=count
    if count > 0:
      ax[i].text(
          patch.get_x() + patch.get_width() / 2,
          count,
          f'{suma_count / len(df_cliente_no_abandono) * 100:.2f}%',
          ha='center',
          va='bottom',
          fontsize=8
      )

fig.delaxes(ax[-1])
plt.show()

# %% [markdown]
# # Comparación de variables entre clientes que continúan y abandonaron la empresa

# %% [markdown]
# ## Mediana del cargo mensual según meses de permanencia

# %%
evolucion= df.groupby(['Meses_permanencia','Abandono'])['Cuenta_mensual'].median().reset_index()

fig, ax = plt.subplots(figsize=(10,8))
fig.suptitle('Evolución de la mediana del cargo mensual según meses de permanencia', fontsize=16)

for abandono, data in evolucion.groupby('Abandono'):
  ax.plot(data['Meses_permanencia'], data['Cuenta_mensual'], label= 'No abandonó' if abandono == 0 else 'Abandonó')

  coef = np.polyfit(data['Meses_permanencia'], data['Cuenta_mensual'], 1)
  tendecia = np.poly1d(coef)
  ax.plot(data['Meses_permanencia'], tendecia(data['Meses_permanencia']), linestyle='--', label=f'Tendencia ({'No abandonó' if abandono == 0 else 'Abandonó'})')

ax.set_xlabel('Meses de permanencia en la empresa')
ax.set_ylabel('Cargo mensual (mediana)')
ax.legend(title='Estado del cliente')
plt.show()

# %% [markdown]
# ## Mediana del número de servicios contratados según meses de permanencia

# %%
evolucion_num_servicios = df.groupby(['Meses_permanencia','Abandono'])['N_servicios'].median().reset_index()

fig, ax = plt.subplots(figsize=(10,8))
fig.suptitle('Evolución de la mediana del número de servicios contratados según meses de permanencia', fontsize=16)

for abandono, data in evolucion_num_servicios.groupby('Abandono'):
  ax.plot(data['Meses_permanencia'], data['N_servicios'], label= 'No abandonó' if abandono == 0 else 'Abandonó')

  coef = np.polyfit(data['Meses_permanencia'], data['N_servicios'], 1)
  tendecia = np.poly1d(coef)
  ax.plot(data['Meses_permanencia'], tendecia(data['Meses_permanencia']), linestyle='--', label=f'Tendencia ({'No abandonó' if abandono == 0 else 'Abandonó'})')

ax.set_xlabel('Meses de permanencia en la empresa')
ax.set_ylabel('Número de servicios (mediana)')
ax.legend(title='Estado del cliente')
plt.show()

# %% [markdown]
# #📊 Informe Final – Proyecto Telecom X LATAM
# ###1. Introducción
# Este análisis busca identificar patrones de churn (fuga de clientes) en Telecom X LATAM, con el objetivo de recomendar acciones concretas que mejoren la retención y optimicen la rentabilidad.
#
# ###2. Preparación de Datos
# Se integraron las fuentes de clientes y servicios.
#
# Se validaron columnas y se documentaron errores encontrados (ej. KeyError en merges, corregido con verificación de nombres).
#
# Se aplicaron transformaciones básicas: limpieza de nulos, normalización de categorías y creación de variables derivadas.
#
# ###3. Exploración Inicial
# Distribución de clientes activos vs. cancelados: proporción clara de churn superior al promedio esperado.
#
# Segmentación por tipo de contrato: contratos mensuales muestran mayor riesgo de fuga.
#
# Servicios adicionales: clientes con múltiples servicios tienden a permanecer más tiempo.
#
# ###4. Visualizaciones Clave
# Gráfico de barras con churn por tipo de contrato (color coding: rojo = alto churn, verde = bajo churn).
#
# Heatmap de correlaciones para identificar variables más influyentes.
#
# Serie temporal de cancelaciones para detectar picos estacionales.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Churn por tipo de contrato
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Tipo_contrato', hue='Abandono', palette={1:'red',0:'green'})
plt.title('Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono')
plt.show()

# %%
# 2. Heatmap de correlaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionar solo columnas numéricas
df_num = df.select_dtypes(include=['int64','float64'])

# Calcular la matriz de correlación
corr = df_num.corr()

# Ajustar tamaño de la figura
plt.figure(figsize=(20,8))

# Crear el mapa de calor
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.1f', center=0)

# Ajustar título y etiquetas
plt.title('Correlación entre las variables', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#3. Evolución temporal del churn
# Agrupar por meses de permanencia y contar abandonos
churn_permanencia = df.groupby('Meses_permanencia')['Abandono'].apply(lambda x: (x==1).sum())

plt.figure(figsize=(10,5))
churn_permanencia.plot(kind='line', marker='o', color='red')
plt.title('Evolución del Churn según Meses de Permanencia')
plt.xlabel('Meses de permanencia')
plt.ylabel('Clientes que Cancelaron')
plt.grid(True)
plt.show()

# %% [markdown]
# ###5. Insights de Negocio
# Mayor riesgo: clientes con contrato mensual y sin servicios adicionales.
#
# Menor riesgo: clientes con contrato anual y múltiples servicios.
#
# Recomendación principal: incentivar migración de contratos mensuales a planes anuales con beneficios adicionales.
#
# ###6. Conclusión y Recomendación Final
# El análisis confirma que los contratos mensuales concentran la mayor tasa de churn.
# Se recomienda:
#
# Implementar campañas de migración hacia contratos anuales.
#
# Ofrecer paquetes de servicios combinados para aumentar la retención.
#
# Monitorear mensualmente la evolución del churn con dashboards claros y reproducibles.
